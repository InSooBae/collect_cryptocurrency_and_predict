# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/pratikpv/cryptocurrency_data_downloader.git '/content/gdrive/My Drive/Colab Notebooks/cryptocurrency_data_downloader'
# Out:
# Cloning into '/content/gdrive/My Drive/Colab Notebooks/cryptocurrency_data_downloader'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15 (delta 3), reused 10 (delta 1), pack-reused 0
# Unpacking objects: 100% (15/15), done.

# %%
# %cd gdrive/MyDrive/Colab\ Notebooks/cryptocurrency_data_downloader
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/cryptocurrency_data_downloader

# %%
# !pip install python-binance
# Out:
# ...
#      |████████████████████████████████| 61kB 4.3MB/s
# ...
#      |████████████████████████████████| 112kB 22.0MB/s
# ...
#      |████████████████████████████████| 184kB 29.7MB/s
# ...
#      |████████████████████████████████| 1.3MB 26.6MB/s
# ...
#      |████████████████████████████████| 286kB 34.8MB/s
# ...
#      |████████████████████████████████| 143kB 50.6MB/s
# ...
#      |████████████████████████████████| 296kB 47.9MB/s
# ...

# %%
# !python download_data_from_binance.py
# Out:
# ------------------------------------------------------------
# ...
# ------------------------------------------------------------
# Step 0:Downloading data from 2019-11-21 00:00:00 to 2019-11-22 00:00:00
# 	 Downloaded data of len 25 from 2019-11-21 00:00:00 to 2019-11-22 00:00:00
# Step 1:Downloading data from 2019-11-22 00:00:00 to 2019-11-23 00:00:00
# 	 Downloaded data of len 25 from 2019-11-22 00:00:00 to 2019-11-23 00:00:00
# Step 2:Downloading data from 2019-11-23 00:00:00 to 2019-11-24 00:00:00
# 	 Downloaded data of len 25 from 2019-11-23 00:00:00 to 2019-11-24 00:00:00
# Step 3:Downloading data from 2019-11-24 00:00:00 to 2019-11-25 00:00:00
# 	 Downloaded data of len 25 from 2019-11-24 00:00:00 to 2019-11-25 00:00:00
# Step 4:Downloading data from 2019-11-25 00:00:00 to 2019-11-26 00:00:00
# 	 Downloaded data of len 23 from 2019-11-25 00:00:00 to 2019-11-26 00:00:00
# Step 5:Downloading data from 2019-11-26 00:00:00 to 2019-11-27 00:00:00
# ...
