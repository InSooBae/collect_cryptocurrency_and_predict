# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/pratikpv/predicting_bitcoin_market.git '/gdrive/My Drive/Colab Notebooks/predicting_bitcoin_market'
# Out:
# Cloning into '/gdrive/My Drive/Colab Notebooks/predicting_bitcoin_market'...
# remote: Enumerating objects: 104, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 104 (delta 71), reused 83 (delta 57), pack-reused 0
# Receiving objects: 100% (104/104), 2.61 MiB | 8.04 MiB/s, done.
# Resolving deltas: 100% (71/71), done.

# %%
# %cd gdrive/MyDrive/Colab\ Notebooks/predicting_bitcoin_market
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/predicting_bitcoin_market

# %%
# !python merge_data_files.py
